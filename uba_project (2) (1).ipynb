# %%
import pandas as pd

# Load data
df = pd.read_excel(r"C:/Users/divya/Downloads/UBA_project.xlsx")

# Show first rows
print(df.head())

# Basic info
print(df.info())

# Summary
print(df.describe())
# Out:
#                     Timestamp Village Name  Ward Nil     District  \
# 0  2025/09/02 11:07:40 PM PDT   Panchjetty       2.0  Thiruvallur
# 1  2026/01/07 10:16:01 PM PST   Panchjetty       4.0  Thiruvallur
# 2  2025/00/13 10:21:50 PM PDT     Orakkadu      14.0  Thiruvallur
# 3  2026/01/07 10:09:06 PM PST  Panchjetty        3.0  Thiruvallur
# 4  2026/01/07 10:10:03 PM PST   Panchjetty       3.0  Thiruvallur
#
#          State Gram Panchjettychayat  Block Name of Respondent  Gender   Age  \
# 0  Tamil Nadu                 Aathur     97           Kasuthri  Female  37.0
# 1  Tamil Nadu             Panchjetty  7/171           Santhosh  Female  69.0
# 2  Tamil Nadu               Orakkadu     97              Meena  Female  65.0
# 3  Tamil Nadu             Panchjetty  7/171             Vimala  Female  35.0
# 4  Tamil Nadu             Panchjetty  7/171             Kumari  Female  55.0
#
#    ... Crop name  Crop iNil previous year (acre) Yield( quintal per acre)  \
# ...

# %%
print("Total Households:", len(df))
# Out:
# Total Households: 1001

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Village Name', 'Ward Nil', 'District', 'State',
#        'Gram Panchjettychayat', 'Block', 'Name of Respondent', 'Gender', 'Age',
#        'Relationship with Head of Household', 'Contact Number',
#        'Name of  Head of Household', 'Gender.1', 'No.of Family members',
#        'Caste', 'House Ownership', 'Toilet Facility', 'Public Toilet',
#        'Waste Collection SHeadyem', 'Drainage Linked To House ',
#        'Fuel for Cooking', 'Compost PIT', 'Bio Gas Plant', 'Name', 'Gender.2',
#        'Age.1', 'Education', 'Occupation', 'Does any member migrate for work ',
#        'If Head,how many members ?', 'Since how many years?',
#        'PM Jan Dhan Yojana (Banking Service)\neg: DeposIT, credIT, insurance ,  pension , post card.',
#        'Sukanya Samridhi Yojana (Gov Bank Service for Girl Child ) max 2 ',
#        'Mudra Yojana (',
#        'PM Jivan Jyoti Bima Yojana (Death Insurance Policy) ',
# ...

# %%
print(df['Gender'].value_counts())
# Out:
# Gender
# Female    826
# Male      174
# Name: count, dtype: int64

# %%
print(df['Education'].value_counts())
# Out:
# Education
# 11th pass                   213
# Nil                         114
# 12th  pass                   97
# 7th Pass                     66
# 9th Pass                     44
# Mechanical engineering       32
# BSC                          28
# Diploma                      27
# Bcom A&F completed           18
# College                      17
# B.Com                        16
# 12th  pass Pass              15
# BA                           15
# 5thth                        15
# BA                           15
# Primary School               15
# B.Sc                         15
# BE engineerimg               14
# 10th Pass                    14
# B.A                          14
# M.com                        14
# B. Com                       13
# BE mechanical                12
# 11th                         11
# 6th                          11
# 9 th                         11
# BA public administration     10
# Bsc(cs)                      10
# IT                            9
# ...

# %%
print(df['Toilet Facility'].value_counts())
# Out:
# Toilet Facility
# Private       641
# Individual    258
# Public         52
# Open           48
# Open            1
# Name: count, dtype: int64

# %%
print(df['Electricity Connection to Household?'].value_counts())
# Out:
# Electricity Connection to Household?
# Nil    1000
# Name: count, dtype: int64

# %%
print(df['Occupation'].value_counts())
# Out:
# Occupation
# Unemployed             338
# Clerk                  133
# Daily Wage Worker       77
# Engineer                77
# Teacher                 61
# Accountant              61
# Shop Assistant          60
# Lab Technician          38
# College Student         19
# Technician              19
# Agriculture Worker      16
# Construction Worker     16
# Software Support        15
# Primary Worker          15
# IT Support              13
# Business Assistant      11
# Driver                   9
# Agriculture Labor        7
# Salesman                 4
# Sales Executive          3
# Shopkeeper               2
# Mechanical Engineer      1
# Mechanic                 1
# Electrician              1
# Lab Assistant            1
# Economist                1
# Employee                 1
# Name: count, dtype: int64

# %%
print(df['Total Land (In acres)'].describe())
# Out:
# count     1000
# unique      21
# top        Nil
# freq       512
# Name: Total Land (In acres), dtype: object

# %%
print(df['PM Awas Yojana (Build House)'].value_counts())
# Out:
# PM Awas Yojana (Build House)
# Nil    1000
# Name: count, dtype: int64

# %%
print(df['Major problems in village'].value_counts())
# Out:
# Major problems in village
# Bus Facility                                            376
# Bus Facility problem                                     47
# Bus Facility                                             20
# Salt water issue                                         20
# No Proper Road                                           19
#                                                        ...
# No Bus Facility                                           1
# No way for agriculture Land\nNo good drinking water       1
#  No proper Toilet, water                                  1
# No Proper Hospital road                                   1
#  No Proper No Proper Schools                              1
# Name: count, Length: 97, dtype: int64
